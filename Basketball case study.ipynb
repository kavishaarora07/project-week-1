# %% [markdown]
# # Basket ball case study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('basketball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# # R-E (INPUT VARIABLES)
# #Q-OUTPUT VARIABLE (TARGET VARIABLE)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#all inputs are integer except ERA that is float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#no null values are present

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# observations
#
# 1. if mean>median, data is right skewed. here, in w (number of wins) mean = 80.966 and median is 81.000 which means its a symmetric distribution. same is with R and In AB, data is right skewed.
# 2. standard deviation is high in all it means data is widespreaded.
# 3. there is not very much gap between 75% percentile and max value. but there are outliers present in the data.

# %%
#w is the output - label

# %%
#lets check the unique values

df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# # SINCE TARGET VARIABLE IS INTEGER, IT MEANS ITS A REGRESSION MODEL

# %%
#univariate analysis

# %%
df['R'].value_counts()
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64

# %%
sns.distplot(df.R, bins=30)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
# R  -  right skewed data

# %%
sns.distplot(df.AB)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
# AB  -  normal distribution

# %%
sns.distplot(df.H)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
# H - Bipolar distributed data

# %%
sns.distplot(df.HR, bins=20)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
# HR - some skewness on both sides

# %%
sns.distplot(df.BB, bins=30)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
#BB- skewness on both side

# %%
sns.distplot(df.SO, bins=30)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
# SO- skewed data on both sides

# %%
sns.distplot(df.SB, bins=30)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
#SB - RIGHT SKEWED

# %%
sns.distplot(df.RA, bins=30)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
#RA - SKEWED DATA

# %%
sns.distplot(df.ER, bins=30)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
#ER - little skewed data

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
sns.distplot(df.ERA,bins=30)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
#ERA - skewed on both sides

# %%
sns.distplot(df.CG, bins=30)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
#CG- not normally distrubuted

# %%
sns.distplot(df.SHO, bins=30)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
#SHO - not normally distributed

# %%
sns.distplot(df.SV, bins=30)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
#SV -right skewed

# %%
sns.distplot(df.E, bins=30)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
#E bipolar data

# %%
sns.distplot(df['2B'],bins=30)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
#2B - LITTLE BIT LEFT SIDE SKEWED

# %%
sns.distplot(df['3B'],bins=30)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
# 3b -normal distribution

# %%
#lets analyse the target variable

# %%
sns.distplot(df.W)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
#its a normal distribution
#w is a TARGET variable and its dependant on input variables

# %%
#bivariate analysis

# %%
sns.scatterplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
#positive correlation. more runs, more wins

# %%
sns.scatterplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
#data is widespreded

# %%
sns.scatterplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
#data is wide spreaded.

# %%
sns.scatterplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
#positive correlation . more 2b more chances to win

# %%
sns.scatterplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
#wide spreaded. low correlation

# %%
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot(x='BB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
#low correlation

# %%
sns.scatterplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
#highly negative correlation

# %%
sns.scatterplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
#highly negative correlation

# %%
sns.scatterplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
#highly negative correlation

# %%
sns.scatterplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
#low correlation

# %%
sns.scatterplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
#low correlation

# %%
sns.pairplot(df)

# %%
#correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df.corr(),annot=True, linecolor='white', linewidth=0.30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #observation
# 1. R , 2B, HR, BB, SHO, SV - highly correlated with wins(target/label)
# 2. AB, BB, H , SO, SB, CG, E - low correlation with wins
# 3. RA, ER, ERA - Highly negative correlated with wins
# 4. multicolinerarity is present. AB AND H are highly correlated with each other(0.74),RA WITH ER AND ERA IS HIGHLY CORRELATED (0.99)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %%
df= df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E','W']]

# %%
df.shape
# Out:
# (30, 17)

# %%
df
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
df.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E   W
# 0   88  95
# 1   86  83
# 2   79  81
# 3  101  76
# 4   86  74

# %%
df.tail()
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV   E   W
# 25  47  75  92
# 26  41  78  84
# 27  44  86  79
# 28  41  92  74
# 29  36  95  68

# %% [markdown]
# # multicolinearity

# %%
# we wont use vif on target variable so removing it

# %%
v= df.drop('W',axis=1)
v
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
#scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
scale= sc.fit_transform(v)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['features']=v.columns

# %%
vif['vif']=[variance_inflation_factor(scale,i) for i in range(len(v.columns))]

# %%
vif
# Out:
#    features          vif
# 0         R    11.522370
# 1        AB    13.311532
# 2         H    10.070668
# 3        2B     4.019297
# 4        3B     3.294146
# 5        HR    10.079902
# 6        BB     3.806098
# 7        SO     2.652401
# 8        SB     2.102684
# 9        RA   191.839155
# 10       ER  1680.387145
# 11      ERA  1222.722240
# 12       CG     3.059904
# 13      SHO     3.654331
# 14       SV     5.798850
# 15        E     2.186219

# %%
#ER has the highest and we need to delete it

# %%
v = df.drop(['W','ER'],axis=1)

# %%
v
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104  641  3.73   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  640  3.67  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68  701  3.98   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83  803  4.64   7   12  35   86
# 5   891  5509  1480  308  17  232  570  1151   88  670  3.80   7   10  34   88
# 6   764  5567  1397  272  19  212  554  1227   63  698  4.03   3    4  48   93
# 7   713  5485  1370  246  20  217  418  1331   44  693  4.05   0   10  43   77
# 8   644  5485  1383  278  32  167  436  1310   87  642  3.74   1   12  60   95
# 9   748  5640  1495  294  33  161  478  1148   71  753  4.31   3   10  40   97
# 10  751  5511  1419  279  32  172  503  1233  101  733  4.24   5    9  45  119
# ...

# %%
scale = sc.fit_transform(v)

# %%
VIF=pd.DataFrame()
VIF['features']=v.columns

VIF['vif']=[variance_inflation_factor(scale,i) for i in range(len(v.columns))]

# %%
VIF
# Out:
#    features         vif
# 0         R   11.158733
# 1        AB    5.863764
# 2         H    9.628749
# 3        2B    3.786446
# 4        3B    3.293109
# 5        HR    9.057309
# 6        BB    3.791451
# 7        SO    2.607389
# 8        SB    1.849280
# 9        RA  122.133235
# 10      ERA  119.328698
# 11       CG    2.741188
# 12      SHO    3.410561
# 13       SV    3.203815
# 14        E    2.107345

# %%
#RA AND ER HAS HIGHEST

# %%
v= df.drop(['W','RA','ER'],axis=1)

# %%
v
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35   86
# 5   891  5509  1480  308  17  232  570  1151   88  3.80   7   10  34   88
# 6   764  5567  1397  272  19  212  554  1227   63  4.03   3    4  48   93
# 7   713  5485  1370  246  20  217  418  1331   44  4.05   0   10  43   77
# 8   644  5485  1383  278  32  167  436  1310   87  3.74   1   12  60   95
# 9   748  5640  1495  294  33  161  478  1148   71  4.31   3   10  40   97
# 10  751  5511  1419  279  32  172  503  1233  101  4.24   5    9  45  119
# 11  729  5459  1363  278  26  230  486  1392  121  3.57   5   13  39   85
# ...

# %%
scale= sc.fit_transform(v)

# %%
vif2= pd.DataFrame()
vif2['features']=v.columns

vif2['vif']=[variance_inflation_factor(scale,i) for i in range(len(v.columns))]

# %%
vif2
# Out:
#    features        vif
# 0         R  10.987898
# 1        AB   4.399954
# 2         H   8.941874
# 3        2B   3.729413
# 4        3B   3.142717
# 5        HR   7.882841
# 6        BB   3.468244
# 7        SO   2.155496
# 8        SB   1.819823
# 9       ERA   4.951981
# 10       CG   2.723370
# 11      SHO   3.227759
# 12       SV   2.948133
# 13        E   2.040676

# %%
v.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56   88
# 1  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45   86
# 2  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38   79
# 3  622  5533  1381  260  27  136  404  1231   68  3.98   7    9  37  101
# 4  689  5605  1515  289  49  151  455  1259   83  4.64   7   12  35   86

# %%
v.corr()
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283  0.402452
# AB   0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983 -0.136414
# H    0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855 -0.118281
# 2B   0.560084  0.453370  0.566847  1.000000  0.220490  0.056292  0.302700
# 3B  -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915 -0.454949
# HR   0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000  0.425691
# BB   0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691  1.000000
# SO  -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567 -0.098347
# ERA -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917 -0.459832
# CG   0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502  0.462478
# SHO -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119  0.426004
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(v.corr(),annot=True,linecolor='blue',linewidth=0.30 )
# Out:
# <AxesSubplot:>

# %%
#checking skewness

# %%
v.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # outliers

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()

# %%
#outliers are in E,SV,SHO,ERA,R.

# %%
#we will follow IQR METHOD.

# %%
IQR = df['E'].quantile(.75)-df['E'].quantile(.25)
IQR
# Out:
# 10.75

# %%
up= df['E'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 112.875

# %%
v['E']=np.where(v['R']>up,up,v['E'])

# %%
IQR = df['ERA'].quantile(.75)-df['ERA'].quantile(.25)
IQR
up= df['ERA'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 5.026250000000001

# %%
v['ERA']=np.where(v['ERA']>up,up,v['ERA'])

# %%
IQR = df['SHO'].quantile(.75)-df['SHO'].quantile(.25)
IQR
up= df['SHO'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 19.0

# %%
v['SHO']=np.where(v['SHO']>up,up,v['SHO'])

# %%
IQR = df['SV'].quantile(.75)-df['SV'].quantile(.25)
IQR
up= df['SV'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 61.0

# %%
v['SV']=np.where(v['SV']>up,up,v['SV'])

# %%
IQR = df['E'].quantile(.75)-df['E'].quantile(.25)
IQR
up= df['E'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 112.875

# %%
v['E']=np.where(v['E']>up,up,v['E'])

# %%
IQR = df['R'].quantile(.75)-df['R'].quantile(.25)
IQR
up= df['R'].quantile(.75) + (1.5 * IQR)
up
# Out:
# 818.75

# %%
v['R']=np.where(v['R']>up,up,v['R'])

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()

# %%
#outliers are removed

# %%
v.skew()
# Out:
# R      0.284282
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.037969
# CG     0.736845
# SHO    0.218030
# SV     0.612333
# E      0.000000
# dtype: float64

# %%
#SKEWNESS SHOULD NOT BE MORE THAN 0.5. -0.5 TO 0.5 ONLY

# %%
from sklearn.preprocessing import power_transform
pt=power_transform(v)

# %%
pt=pd.DataFrame(pt)
pt.columns=v.columns

# %%
pt.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# ERA    0.001204
# CG    -0.059785
# SHO   -0.017889
# SV     0.001270
# E      0.000000
# dtype: float64

# %%
#skewness removed

# %%
#scaling method

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scale= sc.fit_transform(pt)

# %%
x= scale

# %%
y=df['W']

# %%
x.shape
# Out:
# (30, 14)

# %%
y.shape
# Out:
# (30,)

# %%
#train_test

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
lr=LinearRegression()

# %%
#fit the model

# %%
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_test,pred_test),2)==round(r2_score(y_train,pred_train),2):
        print("at random state",i, "the model performs well")
        print("at random state:",i)
        print("r2 score of test is:",round(r2_score(y_test,pred_test),2))
        print('r2 score of train is:',round(r2_score(y_train,pred_train),2))
# Out:
# at random state 153 the model performs well
# at random state: 153
# r2 score of test is: 0.84
# r2 score of train is: 0.84
# at random state 311 the model performs well
# at random state: 311
# r2 score of test is: 0.84
# r2 score of train is: 0.84
# at random state 320 the model performs well
# at random state: 320
# r2 score of test is: 0.85
# r2 score of train is: 0.85
# at random state 332 the model performs well
# at random state: 332
# r2 score of test is: 0.84
# r2 score of train is: 0.84

# %%
#at random state 320 model performs better

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=320)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#now we will apply more regressors, regularisation and ensemble techniques in machine learning

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
ridge = Ridge()
Lasso = Lasso()
DTR = DecisionTreeRegressor()
SVR = SVR()
KNR = KNeighborsRegressor()
RFR = RandomForestRegressor()
ElasticNet = ElasticNet()
Bagging = BaggingRegressor()
ADA = AdaBoostRegressor()
GB= GradientBoostingRegressor()

# %%
algo = [ridge,Lasso,DTR,SVR,KNR,RFR,ElasticNet,Bagging,ADA,GB]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('X' * 50, '\n\n')

# %%
for a in algo:
    a.fit(x_train,y_train)
    print('mean_absoltute_error',a,'algo',mean_absolute_error(y_test,a.predict(x_test)))
    print('mean_squared_error',a,'algo',mean_squared_error(y_test,a.predict(x_test)))
    print('R2 score of',a,'algo',r2_score(y_test,a.predict(x_test))*100)
    print('X'*50,'\n\n')
# Out:
# mean_absoltute_error Ridge() algo 2.6463585820834106
# mean_squared_error Ridge() algo 11.097864620506678
# R2 score of Ridge() algo 87.27633355610699
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absoltute_error Lasso() algo 1.9280335055649
# mean_squared_error Lasso() algo 4.7407119351065345
# R2 score of Lasso() algo 94.56478886420908
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absoltute_error DecisionTreeRegressor() algo 9.666666666666666
# mean_squared_error DecisionTreeRegressor() algo 123.33333333333333
# R2 score of DecisionTreeRegressor() algo -41.401273885350335
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absoltute_error SVR() algo 7.039966295020352
# mean_squared_error SVR() algo 92.96405620550313
# R2 score of SVR() algo -6.582994375736084
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absoltute_error KNeighborsRegressor() algo 4.3
# mean_squared_error KNeighborsRegressor() algo 35.91333333333332
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in algo:
    print('mean_square',i,'algo',mean_squared_error(y_test,i.predict(x_test)))
    print('cross_val_Score of',i,'algo',cross_val_score(i,x,y,cv=10,scoring='neg_mean_squared_error').mean())
    print('X'*50)
# Out:
# mean_square Ridge() algo 11.097864620506678
# cross_val_Score of Ridge() algo -35.938338101249826
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# mean_square Lasso() algo 4.7407119351065345
# cross_val_Score of Lasso() algo -37.64649081725146
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# mean_square DecisionTreeRegressor() algo 123.33333333333333
# cross_val_Score of DecisionTreeRegressor() algo -115.10000000000002
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# mean_square SVR() algo 92.96405620550313
# cross_val_Score of SVR() algo -99.19997648986433
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# mean_square KNeighborsRegressor() algo 35.91333333333332
# cross_val_Score of KNeighborsRegressor() algo -74.51333333333335
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# mean_square RandomForestRegressor() algo 47.02716666666666
# cross_val_Score of RandomForestRegressor() algo -60.45951000000001
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# ...

# %%
for i in algo:
    print('root_mean_square',i,'algo',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,x,y,cv=10,scoring='neg_mean_squared_error').mean()
    print('cross_val_Score of root mean square',i,'=',np.sqrt(-score))
    print('X'*50)
# Out:
# root_mean_square Ridge() algo 3.331345767179786
# cross_val_Score of root mean square Ridge() = 5.994859306209765
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# root_mean_square Lasso() algo 2.177317600881078
# cross_val_Score of root mean square Lasso() = 6.135673623755705
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# root_mean_square DecisionTreeRegressor() algo 11.105554165971787
# cross_val_Score of root mean square DecisionTreeRegressor() = 10.406728592598157
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# root_mean_square SVR() algo 9.641786981960509
# cross_val_Score of root mean square SVR() = 9.959918498153703
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# root_mean_square KNeighborsRegressor() algo 5.992773425829924
# cross_val_Score of root mean square KNeighborsRegressor() = 8.632110595522589
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# root_mean_square RandomForestRegressor() algo 6.857635646975323
# ...

# %% [markdown]
# # hyper tuning of svr model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'kernel' : ['linear','rbf','poly'],
           'gamma':['scaler','auto']}

# %%
GSCV = GridSearchCV(SVR,parameters,cv=10,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(), n_jobs=-1,
#              param_grid={'gamma': ['scaler', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              scoring='neg_mean_squared_error')

# %%
GSCV.best_params_
# Out:
# {'gamma': 'auto', 'kernel': 'linear'}

# %%
GSCV_predict= GSCV.best_estimator_.predict(x_test)
mean_squared_error(y_test,GSCV_predict)
# Out:
# 9.423267770134467

# %% [markdown]
# # saving the best model

# %%
import joblib
joblib.dump(GSCV.best_estimator_,"Basketball.pkl")
# Out:
# ['Basketball.pkl']
